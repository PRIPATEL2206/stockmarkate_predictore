# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df =pd.read_csv("../data/NIFTY 50 and bank nifty -13-05-2023-to-13-05-2024.csv")
df.head()
# Out:
#         Date  Nifty50_Open   Nifty50_High  Nifty50_Low  Nifty50_Close  \
# 0  15-May-23       18339.30      18458.90     18287.90       18398.85
# 1  16-May-23       18432.35      18432.35     18264.35       18286.50
# 2  17-May-23       18300.45      18309.00     18115.35       18181.75
# 3  18-May-23       18287.50      18297.20     18104.85       18129.95
# 4  19-May-23       18186.15      18218.10     18060.40       18203.40
#
#    Nifty50_Shares Traded  Nifty50_Turnover (? Cr)  Bank_Open   Bank_High   \
# 0            216088535.0                 19329.75    43821.05    44151.70
# 1            219490491.0                 21063.78    44144.15    44144.15
# 2            229898510.0                 20903.12    43948.50    43992.75
# 3            272103515.0                 24172.44    44006.90    44079.20
# 4            260898407.0                 22105.67    43930.00    44020.90
#
#    Bank_Low  ...  Next_Nifty50_Low  Next_Nifty50_Close  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                            1
# Nifty50_Open                    1
# Nifty50_High                    1
# Nifty50_Low                     1
# Nifty50_Close                   1
# Nifty50_Shares Traded           1
# Nifty50_Turnover (? Cr)         1
# Bank_Open                       1
# Bank_High                       1
# Bank_Low                        1
# Bank_Close                      1
# Bank_Shares Traded              1
# Bank_Turnover (? Cr)            1
# Next_Date                       1
# Next_Nifty50_Open               1
# Next_Nifty50_High               1
# Next_Nifty50_Low                1
# Next_Nifty50_Close              1
# Next_Nifty50_Shares Traded      1
# Next_Nifty50_Turnover (? Cr)    1
# Next_Bank_Open                  1
# Next_Bank_High                  1
# Next_Bank_Low                   1
# Next_Bank_Close                 1
# Next_Bank_Shares Traded         1
# Next_Bank_Turnover (? Cr)       1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Date                            0
# Nifty50_Open                    0
# Nifty50_High                    0
# Nifty50_Low                     0
# Nifty50_Close                   0
# Nifty50_Shares Traded           0
# Nifty50_Turnover (? Cr)         0
# Bank_Open                       0
# Bank_High                       0
# Bank_Low                        0
# Bank_Close                      0
# Bank_Shares Traded              0
# Bank_Turnover (? Cr)            0
# Next_Date                       0
# Next_Nifty50_Open               0
# Next_Nifty50_High               0
# Next_Nifty50_Low                0
# Next_Nifty50_Close              0
# Next_Nifty50_Shares Traded      0
# Next_Nifty50_Turnover (? Cr)    0
# Next_Bank_Open                  0
# Next_Bank_High                  0
# Next_Bank_Low                   0
# Next_Bank_Close                 0
# Next_Bank_Shares Traded         0
# Next_Bank_Turnover (? Cr)       0
# dtype: int64

# %%
trainx_x_col=df.columns[1:13]
trainx_x_col
# Out:
# Index(['Nifty50_Open ', 'Nifty50_High', 'Nifty50_Low', 'Nifty50_Close',
#        'Nifty50_Shares Traded', 'Nifty50_Turnover (? Cr)', 'Bank_Open ',
#        'Bank_High ', 'Bank_Low', 'Bank_Close', 'Bank_Shares Traded',
#        'Bank_Turnover (? Cr)'],
#       dtype='object')

# %%
trainx_y_col=df.columns[20:24]
trainx_y_col
# Out:
# Index(['Next_Bank_Open ', 'Next_Bank_High ', 'Next_Bank_Low',
#        'Next_Bank_Close'],
#       dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(df[trainx_x_col], df[trainx_y_col], test_size= 0.2, random_state= 1)

# %%
x_train
# Out:
#      Nifty50_Open   Nifty50_High  Nifty50_Low  Nifty50_Close  \
# 169       22080.50      22124.15     21969.80       22032.30
# 159       21751.35      21755.60     21555.65       21665.80
# 180       21780.65      21832.95     21658.75       21697.45
# 147       21110.40      21210.90     21074.45       21182.70
# 150       21477.65      21505.05     21337.75       21453.10
# ..             ...           ...          ...            ...
# 137       20108.50      20158.70     20015.85       20133.15
# 72        19297.40      19339.55     19229.70       19265.80
# 140       20808.90      20864.05     20711.15       20855.10
# 235       22421.55      22476.45     22384.00       22402.40
# 37        19385.70      19512.20     19373.00       19497.30
#
#      Nifty50_Shares Traded  Nifty50_Turnover (? Cr)  Bank_Open   Bank_High   \
# 169            292433764.0                 24435.94    48109.95    48305.40
# 159            263711568.0                 25316.13    48194.80    48223.55
# ...

# %%
y_train
# Out:
#      Next_Bank_Open   Next_Bank_High   Next_Bank_Low  Next_Bank_Close
# 169         46573.95         47212.75       45979.60         46064.45
# 159         47796.30         47798.75       47481.35         47704.95
# 180         46568.20         46892.35       45901.25         45970.95
# 147         47939.90         48219.95       47632.85         48143.55
# 150         48085.35         48166.15       47202.65         47445.30
# ..               ...              ...            ...              ...
# 137         44580.15         44951.10       44531.75         44814.20
# 72          44253.65         44610.40       44201.45         44494.65
# 140         47256.75         47259.85       46750.20         46834.55
# 235         47772.65         48625.45       47737.20         48494.95
# 37          45118.05         45227.25       44844.80         44925.00
#
# [196 rows x 4 columns]

# %%
l1=LinearRegression()
l1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
score1=l1.score(x_test,y_test)

# %%
score1
# Out:
# 0.9647259115411853

# %%
testData=[21990.95,	22131.3	,21950.3,	22055.2,	265804411,	28717.71,	47555.5	,47868.7,	47313.35,	47421.1,	218854712,	10013.36]

# %%
l1.predict(np.array([testData]))
# Out:
# c:\Users\baps\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[47366.60658385, 47611.05966856, 47122.94597323, 47356.06718778]])

# %%
from sklearn.preprocessing import PolynomialFeatures
 
poly = PolynomialFeatures(degree=4)
X_poly = poly.fit_transform(x_train)
 
poly.fit(X_poly, y_train)
lin2 = LinearRegression()
lin2.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
lin2.predict(np.array(poly.fit_transform([testData])))
# Out:
# array([[49025.29926237, 49168.28940694, 49291.12432845, 49941.36782254]])

# %%
lin2.score(poly.fit_transform(x_test),y_test)
# Out:
# 0.06932750529774731

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Date', 'Nifty50_Open ', 'Nifty50_High', 'Nifty50_Low', 'Nifty50_Close',
#        'Nifty50_Shares Traded', 'Nifty50_Turnover (? Cr)', 'Bank_Open ',
#        'Bank_High ', 'Bank_Low', 'Bank_Close', 'Bank_Shares Traded',
#        'Bank_Turnover (? Cr)', 'Next_Date', 'Next_Nifty50_Open ',
#        'Next_Nifty50_High', 'Next_Nifty50_Low', 'Next_Nifty50_Close',
#        'Next_Nifty50_Shares Traded', 'Next_Nifty50_Turnover (? Cr)',
#        'Next_Bank_Open ', 'Next_Bank_High ', 'Next_Bank_Low',
#        'Next_Bank_Close', 'Next_Bank_Shares Traded',
#        'Next_Bank_Turnover (? Cr)'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit_transform(df[["Nifty50_Shares Traded"]])
# Out:
# array([[0.27291661],
#        [0.27806537],
#        [0.29381763],
#        [0.35769377],
#        [0.34073514],
#        [0.34325134],
#        [0.35504625],
#        [0.29793881],
#        [0.30292441],
#        [0.24655164],
#        [0.34743312],
#        [0.30061738],
#        [1.        ],
#        [0.34789743],
#        [0.35590812],
#        [0.33349028],
#        [0.28003203],
#        [0.33954141],
#        [0.37943543],
#        [0.28150155],
#        [0.21748631],
#        [0.29876574],
#        [0.34142554],
#        [0.3439234 ],
#        [0.35870438],
#        [0.27855683],
#        [0.26619788],
#        [0.27502459],
#        [0.32832385],
#        [0.26455252],
#        [0.20508697],
#        [0.28256662],
#        [0.54941827],
#        [0.32107237],
#        [0.28799335],
#        [0.28930464],
#        [0.28552423],
#        [0.35187866],
#        [0.30472077],
#        [0.35185572],
#        [0.32615318],
#        [0.44220314],
#        [0.41571881],
# ...

# %%
plt.figure(figsize=(30,30))
# plt.plot(df["Date"],df["Nifty50_Open "],label = "Nifty50_Open ")
# plt.plot(df["Date"],df["Bank_Open "],label = "Bank_close ")
# plt.plot(df["Date"],df["Nifty50_Close"],label = "Bank_Open ")
# plt.plot(df["Date"],df["Bank_Close"],label = "Bank_close ")
plt.subplot(121)
plt.plot(df["Date"],scaler.fit_transform(df[["Nifty50_Shares Traded"]]),label = "Nifty50_Shares Traded")
plt.plot(df["Date"],scaler.fit_transform(df[["Nifty50_Turnover (? Cr)"]]),label = "Nifty50_Turnover (? Cr) ")
plt.legend() 
plt.show()

# %%
plt.figure(figsize=(30,30))
plt.subplot(121)
plt.plot(df["Date"],scaler.fit_transform(df[["Bank_Shares Traded"]]),label = "Bank_Shares Traded")
plt.plot(df["Date"],scaler.fit_transform(df[["Bank_Turnover (? Cr)"]]),label = "Bank_Turnover (? Cr) ")
plt.legend() 
plt.show()
